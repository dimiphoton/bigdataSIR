# %%
import numpy as np
import random
import pandas as pd
from scipy.integrate import odeint
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.dates as mdates
from matplotlib import dates
from sklearn.metrics import mean_squared_error, r2_score
from datetime import datetime
from lmfit import Minimizer, Parameters, Parameter, report_fit, printfuncs, conf_interval
from statsmodels.tsa.arima_model import ARIMA

# %% [markdown]
# # step 0: data importation #

# %%
csv_url="https://raw.githubusercontent.com/ADelau/proj0016-epidemic-data/main/data.csv"
data = pd.read_csv(csv_url)

# %%
data
# Out:
#     Day  num_positive  num_tested  num_hospitalised  \
# 0     1             0           0                 1
# 1     2             5           8                 1
# 2     3            10          12                 2
# 3     4            11          16                 2
# 4     5             9          12                 2
# ..  ...           ...         ...               ...
# 66   67          1550        1942               555
# 67   68          1699        2131               608
# 68   69          1799        2249               671
# 69   70          1884        2372               738
# 70   71          2035        2539               774
#
#     num_cumulative_hospitalizations  num_critical  num_fatalities
# 0                                 1             0               0
# 1                                 1             0               0
# 2                                 2             0               0
# 3                                 2             0               0
# 4                                 2             0               0
# ..                              ...           ...             ...
# 66                             1197            55              38
# 67                             1297            57              39
# 68                             1412            62              41
# 69                             1539            67              41
# 70                             1654            76              43
#
# [71 rows x 7 columns]

# %%
test2=data['num_tested']
data2=data.rolling(7, min_periods=1, center=True).mean()

# %% [markdown]
# # step 1: setting up the model #

# %% [markdown]
# ## step 1.1: writing the ode system ##

# %% [raw]
# here I write the relation between y' and y
# remember: y=[S,E,I,C,R,H,ICU,D]

# %%
def deriv(y, t, N, ps):
    S,E,I,C,R,H,ICU,D = y
    try:
        beta_SE = ps['beta_SE'].value
        gamma_ER = ps['gamma_ER'].value
        fraction_symptomatic = ps['fraction_symptomatic'].value
        days_EtoI=ps['days_EtoI'].value
        days_ItoH=ps['days_ItoH'].value
        days_ItoR=ps['days_ItoR'].value
        days_HtoR=ps['days_HtoR'].value
        days_HtoICU=ps['days_HtoICU'].value
        days_ICUtoD=ps['days_ICUtoD'].value
        days_ICUtoH=ps['days_ICUtoH'].value
        
    except:
        beta_SE, gamma_ER, fraction_symptomatic, days_EtoI, days_ItoH, days_ItoR, days_HtoR, days_HtoICU, days_ICUtoD, days_ICUtoH= ps
    
    #beta = beta_i*(1.1-tau*t) idée de faire régresser beta
    dSdt = -beta_SE*(S*(I+C))/(N-D)
    dEdt = beta_SE*(S*(I+C))/(N-D)-gamma_ER*E
    dIdt = (fraction_symptomatic)*E/days_EtoI-I*(1/days_ItoH+1/days_ItoR)
    dCdt = (1-fraction_symptomatic)*E/days_EtoI-C/days_ItoR
    dRdt = (C+I)/days_ItoR+H/days_HtoR
    dHdt = I/days_ItoH*I+ICU/days_ICUtoH-H*(1/days_HtoICU+1/days_HtoR)
    dICUdt = H/days_HtoICU-ICU*(1/days_ICUtoD+1/days_ICUtoH)
    dDdt = ICU/days_ICUtoD
    
    return dSdt, dEdt, dIdt, dCdt, dRdt, dHdt, dICUdt, dDdt

# %% [markdown]
# ## step 1.2: writing the parameters values and guesses ##

# %%
# the lmfit module uises an orderd dict structure
# to store the parameters to be optimized
# https://lmfit.github.io/lmfit-py/parameters.html

params = Parameters()
params.add('beta_SE', value=0.15, min=1, max=10)
params.add('gamma_ER', value= 0.05, min=0.1, max=2)
params.add('fraction_symptomatic', value= 0.6, min=0.5, max=0.7)
params.add('days_EtoI', value= 3, min=1, max=5)
params.add('days_ItoH',value=5, min=1,max=20)
params.add('days_ItoR',value=10,min=1,max=50)
params.add('days_HtoR',value=12,min=1,max=100)
params.add('days_HtoICU',value=5,min=1,max=50)
params.add('days_ICUtoD',value=2,min=1,max=50)
params.add('days_ICUtoH',value=6,min=1,max=50)
params.add('E0',value=10,min=1,max=40)
params.add('I0',value=5,min=1,max=20)
params.add('C0',value=5,min=0,max=20)
params.add('OBS_Tr_EI_to_nbTest',value=0.25,min=0.05,max=1)
params.add('OBS_nbTest_to_nbpos',value=0.75,min=0.5,max=0.9)
# params.add('OBS_H_to_ICU',value=0.1,min=0.01,max=0.5) mistake??

# %% [markdown]
# ## step 1.3 writing the solver ##

# %%
params
# Out:
# Parameters([('beta_SE', <Parameter 'beta_SE', value=0.15, bounds=[0.001:2]>),
#             ('gamma_ER', <Parameter 'gamma_ER', value=0.1, bounds=[0.1:2]>),
#             ('fraction_symptomatic',
#              <Parameter 'fraction_symptomatic', value=0.6, bounds=[0.5:0.7]>),
#             ('days_EtoI', <Parameter 'days_EtoI', value=3, bounds=[1:5]>),
#             ('days_ItoH', <Parameter 'days_ItoH', value=5, bounds=[1:20]>),
#             ('days_ItoR', <Parameter 'days_ItoR', value=10, bounds=[1:50]>),
#             ('days_HtoR', <Parameter 'days_HtoR', value=12, bounds=[1:100]>),
#             ('days_HtoICU', <Parameter 'days_HtoICU', value=5, bounds=[1:50]>),
#             ('days_ICUtoD', <Parameter 'days_ICUtoD', value=2, bounds=[1:50]>),
#             ('days_ICUtoH', <Parameter 'days_ICUtoH', value=6, bounds=[1:50]>),
#             ('E0', <Parameter 'E0', value=10, bounds=[1:40]>),
#             ('I0', <Parameter 'I0', value=5, bounds=[1:20]>),
#             ('C0', <Parameter 'C0', value=5, bounds=[0:20]>),
#             ('OBS_Tr_EI_to_nbTest',
#              <Parameter 'OBS_Tr_EI_to_nbTest', value=0.25, bounds=[0.05:1]>),
#             ('OBS_nbTest_to_nbpos',
#              <Parameter 'OBS_nbTest_to_nbpos', value=0.75, bounds=[0.5:0.9]>)])

# %%
# this function generate the observation dataframe
def create_obsdf(model,ps,data):
    result=pd.DataFrame(columns=data.columns)
    result['Day']=data['Day']
    nb_trans_EI=ps['beta_SE']*(model['S']*(model['I']+model['C']))/(10**6-model['D'])
    result['num_tested']=ps['OBS_Tr_EI_to_nbTest'].value*nb_trans_EI
    result['num_positive']=ps['OBS_nbTest_to_nbpos'].value*result['num_tested']
    result['num_hospitalised']=model['H']
    result['num_cumulative_hospitalizations']=result['num_hospitalised'].diff().fillna(0).cumsum()
    result['num_critical']=model['ICU']
    result['num_fatalities']=model['D']
    return result
    

#test['num_tested']=params['OBS_Tr_EI_to_nbTest'].value*

# %% [markdown]
# # step 2: fitting the model #

# %% [markdown]
# ## step 2.1: write objective function ##

# %%
#this function compute residuals,
#ie objective function to be minimized in the optimization function
def residual(ps, ts, data, N):
    E0=ps['E0'].value
    I0 = ps['I0'].value
    C0=ps['C0'].value
    S0=N-I0-E0-C0-1
    R0=0
    H0=1
    ICU0=0
    D0=0
    
    y0 = S0,E0,I0,C0,R0,H0,ICU0,D0
    
    model = pd.DataFrame(odesol(y0,ts,N,ps), columns=['S','E','I','C','R','H','ICU','D'])
    obs_df=create_obsdf(model,ps,data)
    component1=(obs_df['num_positive']-data['num_positive']).ravel()
    component2=(obs_df['num_hospitalised']-data['num_hospitalised']).ravel()
    component3=(obs_df['num_critical']-data['num_critical']).ravel()
    component4=(obs_df['num_fatalities']-data['num_fatalities']).ravel()
    # penalty function to think more about !!!
    return (component1+component2+component3+component4)

# %%
np.log(2)
# Out:
# 0.6931471805599453

# %% [raw]
# little test

# %%
t = np.linspace(0, data.shape[0]-1, data.shape[0])
residual(params,data.shape[0] - 1,data, 1e6)
# Out:
# array([2.81244094e-01, 5.44235079e-01, 4.64732937e-01, 6.13575715e+00,
#        1.56935540e+01, 2.43164779e+01, 3.62256815e+01, 3.46881298e+01,
#        4.90219425e+01, 6.26040003e+01, 6.58798249e+01, 9.43758544e+01,
#        1.15714355e+02, 1.42631321e+02, 1.65997838e+02, 2.06845490e+02,
#        2.59396534e+02, 3.08099738e+02, 3.75672870e+02, 4.42153151e+02,
#        5.45957106e+02, 6.52951605e+02, 7.94538188e+02, 9.47753155e+02,
#        1.14638644e+03, 1.35012272e+03, 1.62570916e+03, 1.94815451e+03,
#        2.33096585e+03, 2.77742993e+03, 3.29794784e+03, 3.91643297e+03,
#        4.69778477e+03, 5.55745313e+03, 6.64511051e+03, 7.90245403e+03,
#        9.36416290e+03, 1.11600427e+04, 1.32563947e+04, 1.57806579e+04,
#        1.87783802e+04, 2.23115922e+04, 2.65076703e+04, 3.15858035e+04,
#        3.75202040e+04, 4.46242440e+04, 5.30837513e+04, 6.31387705e+04,
#        7.51711916e+04, 8.94747867e+04, 1.06583388e+05, 1.27020214e+05,
#        1.51528762e+05, 1.80956287e+05, 2.16337813e+05, 2.58852030e+05,
#        3.10358772e+05, 3.72773526e+05, 4.48933879e+05, 5.42296302e+05,
#        6.57738063e+05, 8.01689129e+05, 9.83504004e+05, 1.21720197e+06,
#        1.52467162e+06, 1.94341431e+06, 2.54792632e+06, 3.53273911e+06,
#        8.50969563e+15, 8.39259017e+05, 9.64963887e+05])

# %% [markdown]
# ## step 2.2: write optimization command ##

# %%
#mini = Minimizer(residual, params, (data.shape[0] - 1, data, 1e6))
mini = Minimizer(residual, params, (data.shape[0] - 1, data, 1e6))
result=mini.minimize(method='differential_evolution')
#result = mini.minimize()
result
# Out:
# <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>differential_evolution</td><td></td></tr><tr><td># function evals</td><td>16001</td><td></td></tr><tr><td># data points</td><td>71</td><td></td></tr><tr><td># variables</td><td>15</td><td></td></tr><tr><td>chi-square</td><td> 5.0362e+24</td><td></td></tr><tr><td>reduced chi-square</td><td> 8.9933e+22</td><td></td></tr><tr><td>Akaike info crit.</td><td> 3765.73731</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 3799.67751</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> beta_SE </td><td>  1.66998329 </td><td> 0.15 </td><td>  1.0000e-03 </td><td>  2.00000000 </td><td> True </td></tr><tr><td> gamma_ER </td><td>  1.92937815 </td><td> 0.1 </td><td>  0.10000000 </td><td>  2.00000000 </td><td> True </td></tr><tr><td> fraction_symptomatic </td><td>  0.66243524 </td><td> 0.6 </td><td>  0.50000000 </td><td>  0.70000000 </td><td> True </td></tr><tr><td> days_EtoI </td><td>  1.10122195 </td><td> 3 </td><td>  1.00000000 </td><td>  5.00000000 </td><td> True </td></tr><tr><td> days_ItoH </td><td>  12.2966363 </td><td> 5 </td><td>  1.00000000 </td><td>  20.0000000 </td><td> True </td></tr><tr><td> days_ItoR </td><td>  48.5546979 </td><td> 10 </td><td>  1.00000000 </td><td>  50.0000000 </td><td> True </td></tr><tr><td> days_HtoR </td><td>  74.3428854 </td><td> 12 </td><td>  1.00000000 </td><td>  100.000000 </td><td> True </td></tr><tr><td> days_HtoICU </td><td>  30.8760012 </td><td> 5 </td><td>  1.00000000 </td><td>  50.0000000 </td><td> True </td></tr><tr><td> days_ICUtoD </td><td>  49.8894525 </td><td> 2 </td><td>  1.00000000 </td><td>  50.0000000 </td><td> True </td></tr><tr><td> days_ICUtoH </td><td>  6.26630780 </td><td> 6 </td><td>  1.00000000 </td><td>  50.0000000 </td><td> True </td></tr><tr><td> E0 </td><td>  31.7497889 </td><td> 10 </td><td>  1.00000000 </td><td>  40.0000000 </td><td> True </td></tr><tr><td> I0 </td><td>  9.77101076 </td><td> 5 </td><td>  1.00000000 </td><td>  20.0000000 </td><td> True </td></tr><tr><td> C0 </td><td>  3.76287327 </td><td> 5 </td><td>  0.00000000 </td><td>  20.0000000 </td><td> True </td></tr><tr><td> OBS_Tr_EI_to_nbTest </td><td>  0.70412574 </td><td> 0.25 </td><td>  0.05000000 </td><td>  1.00000000 </td><td> True </td></tr><tr><td> OBS_nbTest_to_nbpos </td><td>  0.82976701 </td><td> 0.75 </td><td>  0.50000000 </td><td>  0.90000000 </td><td> True </td></tr></table>

# %%
E0=result.params['E0'].value
I0 = result.params['I0'].value
C0=result.params['C0'].value
S0=1e6-I0-E0-C0-1
R0=0
H0=1
ICU0=0
D0=0

y0 = S0,E0,I0,C0,R0,H0,ICU0,D0

model = pd.DataFrame(odesol(y0,70,1e6,result.params), columns=['S','E','I','C','R','H','ICU','D'])
obs_df=create_obsdf(model,result.params,data)
obs_df.head(30)
# Out:
#     Day  num_positive    num_tested  num_hospitalised  \
# 0     1  1.320447e+01  1.591346e+01      1.000000e+00
# 1     2  3.322415e+01  4.004033e+01      2.436727e+01
# 2     3  5.783140e+01  6.969595e+01      9.783883e+01
# 3     4  9.935046e+01  1.197330e+02      3.063105e+02
# 4     5  1.706207e+02  2.056249e+02      9.070699e+02
# 5     6  2.930009e+02  3.531122e+02      2.657632e+03
# 6     7  5.029842e+02  6.061752e+02      7.788180e+03
# 7     8  8.627982e+02  1.039808e+03      2.286542e+04
# 8     9  1.477953e+03  1.781166e+03      6.720667e+04
# 9    10  2.525606e+03  3.043754e+03      1.975065e+05
# 10   11  4.298314e+03  5.180146e+03      5.794424e+05
# 11   12  7.265882e+03  8.756533e+03      1.693566e+06
# 12   13  1.214888e+04  1.464132e+04      4.916409e+06
# 13   14  1.997686e+04  2.407527e+04      1.411199e+07
# 14   15  3.209922e+04  3.868462e+04      3.979448e+07
# 15   16  5.032050e+04  6.064414e+04      1.093608e+08
# 16   17  7.870966e+04  9.485755e+04      2.909458e+08
# 17   18  1.403854e+05  1.691865e+05      7.538231e+08
# 18   19  2.242339e+12  2.702372e+12      1.764127e+09
# 19   20  1.646190e+01  1.983918e+01      5.481114e+00
# 20   21  1.717648e+01  2.070036e+01      5.696724e+00
# 21   22  1.792907e+01  2.160736e+01      5.950049e+00
# 22   23  1.872045e+01  2.256110e+01      6.242275e+00
# 23   24  1.955158e+01  2.356274e+01      6.575146e+00
# 24   25  2.042361e+01  2.461367e+01      6.950907e+00
# 25   26  2.133784e+01  2.571546e+01      7.372278e+00
# 26   27  2.229573e+01  2.686987e+01      7.842434e+00
# 27   28  2.329890e+01  2.807885e+01      8.365011e+00
# 28   29  2.434908e+01  2.934448e+01      8.944113e+00
# 29   30  2.544815e+01  3.066903e+01      9.584330e+00
#
#     num_cumulative_hospitalizations  num_critical  num_fatalities
# 0                      0.000000e+00  0.000000e+00        0.000000
# 1                      2.336727e+01  3.042954e-01        0.001885
# 2                      9.683883e+01  1.912322e+00        0.020666
# 3                      3.053105e+02  7.148676e+00        0.101946
# 4                      9.060699e+02  2.267021e+01        0.373470
# 5                      2.656632e+03  6.799261e+01        1.202525
# 6                      7.787180e+03  2.004953e+02        3.660040
# 7                      2.286442e+04  5.890633e+02       10.887249
# 8                      6.720567e+04  1.730750e+03       32.119302
# 9                      1.975055e+05  5.086624e+03       94.515361
# 10                     5.794414e+05  1.493935e+04      277.842272
# 11                     1.693565e+06  4.377768e+04      815.640015
# 12                     4.916408e+06  1.277012e+05     2387.724600
# 13                     1.411199e+07  3.695574e+05     6953.723414
# 14                     3.979448e+07  1.055754e+06    20074.028890
# 15                     1.093608e+08  2.957706e+06    57152.248349
# 16                     2.909458e+08  8.067774e+06   159475.755318
# 17                     7.538231e+08  2.137225e+07   433798.774059
# 18                     1.764127e+09  4.874195e+07  1000000.000000
# 19                     4.481114e+00  5.981647e+01       17.954704
# 20                     4.696724e+00  6.097482e+01       19.317970
# 21                     4.950049e+00  6.225602e+01       20.708729
# 22                     5.242275e+00  6.368376e+01       22.130021
# 23                     5.575146e+00  6.528155e+01       23.585420
# 24                     5.950907e+00  6.707325e+01       25.079035
# 25                     6.372278e+00  6.908336e+01       26.615516
# 26                     6.842434e+00  7.133738e+01       28.200082
# 27                     7.365011e+00  7.386214e+01       29.838538
# 28                     7.944113e+00  7.668604e+01       31.537313
# 29                     8.584330e+00  7.983940e+01       33.303500

# %%
plt.plot(result.residual,label='residu')
plt.plot(data['num_positive'],label='data')
plt.plot(obs_df['num_positive'],label='sim')
plt.legend()

# %%
R2 = 1 - sum(result.residual**2) / sum((data['num_positive'] - np.mean(data['num_positive']))**2)
R2
# Out:
# -2.534629212709539e+17

# %%
# confidence intervals
ci = conf_interval(mini, result)
printfuncs.report_ci(ci)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-95-59e5cf6bcdc4> in <module>
#       1 # confidence intervals
# ----> 2 ci = conf_interval(mini, result)
#       3 printfuncs.report_ci(ci)
#
# ~\anaconda3\lib\site-packages\lmfit\confidence.py in conf_interval(minimizer, result, p_names, sigmas, trace, maxiter, verbose, prob_func)
#     136     ci = ConfidenceInterval(minimizer, result, p_names, prob_func, sigmas,
#     137                             trace, verbose, maxiter)
# --> 138     output = ci.calc_all_ci()
#     139     if trace:
#     140         return output, ci.trace_dict
#
# ~\anaconda3\lib\site-packages\lmfit\confidence.py in calc_all_ci(self)
#     210
#     211         for p in self.p_names:
# --> 212             out[p] = (self.calc_ci(p, -1)[::-1] +
#     213                       [(0., self.params[p].value)] +
#     214                       self.calc_ci(p, 1))
#
# ~\anaconda3\lib\site-packages\lmfit\confidence.py in calc_ci(self, para, direction)
#     234
#     235         para.vary = False
# --> 236         limit, max_prob = self.find_limit(para, direction)
#     237         start_val = a_limit = float(para.value)
#     238         ret = []
#
# ~\anaconda3\lib\site-packages\lmfit\confidence.py in find_limit(self, para, direction)
#     297                 bound_reached = True
#     298
# --> 299             new_prob = self.calc_prob(para, limit)
#     300             rel_change = (new_prob - old_prob) / max(new_prob, old_prob, 1e-12)
#     301             old_prob = new_prob
#
# ~\anaconda3\lib\site-packages\lmfit\confidence.py in calc_prob(self, para, val, offset, restore)
#     340         self.params[para.name] = para
#     341         self.minimizer.prepare_fit(self.params)
# --> 342         out = self.minimizer.leastsq()
#     343         prob = self.prob_func(self.result, out)
#     344
#
# ~\anaconda3\lib\site-packages\lmfit\minimizer.py in leastsq(self, params, max_nfev, **kws)
#    1644         result.call_kws = lskws
#    1645         try:
# -> 1646             lsout = scipy_leastsq(self.__residual, variables, **lskws)
#    1647         except AbortFitException:
#    1648             pass
#
# ~\anaconda3\lib\site-packages\scipy\optimize\minpack.py in leastsq(func, x0, args, Dfun, full_output, col_deriv, ftol, xtol, gtol, maxfev, epsfcn, factor, diag)
#     420         if maxfev == 0:
#     421             maxfev = 200*(n + 1)
# --> 422         retval = _minpack._lmdif(func, x0, args, full_output, ftol, xtol,
#     423                                  gtol, maxfev, epsfcn, factor, diag)
#     424     else:
#
# ~\anaconda3\lib\site-packages\lmfit\minimizer.py in __residual(self, fvars, apply_bounds_transformation)
#     574             raise AbortFitException("fit aborted: too many function evaluations (%d)." % self.max_nfev)
#     575
# --> 576         out = self.userfcn(params, *self.userargs, **self.userkws)
#     577
#     578         if callable(self.iter_cb):
#
# <ipython-input-69-6812e3ebaa57> in residual(ps, ts, data2, N)
#      14
#      15     model = pd.DataFrame(odesol(y0,ts,N,ps), columns=['S','E','I','C','R','H','ICU','D'])
# ---> 16     obs_df=create_obsdf(model,ps,data)
#      17     component1=(obs_df['num_positive']-data['num_positive']).ravel()
#      18     component2=(obs_df['num_hospitalised']-data['num_hospitalised']).ravel()
#
# <ipython-input-18-71a00930f2a8> in create_obsdf(model, ps, data)
#       2 def create_obsdf(model,ps,data):
#       3     result=pd.DataFrame(columns=data.columns)
# ----> 4     result['Day']=data['Day']
#       5     nb_trans_EI=ps['beta_SE']*(model['S']*(model['I']+model['C']))/(10**6-model['D'])
#       6     result['num_tested']=ps['OBS_Tr_EI_to_nbTest'].value*nb_trans_EI
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3042         else:
#    3043             # set column
# -> 3044             self._set_item(key, value)
#    3045
#    3046     def _setitem_slice(self, key: slice, value):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3119         self._ensure_valid_index(value)
#    3120         value = self._sanitize_column(key, value)
# -> 3121         NDFrame._set_item(self, key, value)
#    3122
#    3123         # check if we are modifying a copy
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _set_item(self, key, value)
#    3580             return
#    3581
# -> 3582         NDFrame._iset_item(self, loc, value)
#    3583
#    3584     def _set_is_copy(self, ref, copy: bool_t = True) -> None:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _iset_item(self, loc, value)
#    3569
#    3570     def _iset_item(self, loc: int, value) -> None:
# -> 3571         self._mgr.iset(loc, value)
#    3572         self._clear_item_cache()
#    3573
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in iset(self, loc, value)
#    1113                 else:
#    1114                     blk.delete(blk_locs)
# -> 1115                     self._blklocs[blk.mgr_locs.indexer] = np.arange(len(blk))
#    1116
#    1117         if len(removed_blknos):
#
# KeyboardInterrupt:
